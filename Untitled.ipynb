# %% [markdown]
# Using a flight crash data to get insights

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d as mpl

# %%
import numpy as np

# %%
air = pd.read_csv("airplane.csv")

# %%
air.head()
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# ...

# %%
air.columns
# Out:
# Index(['Date', 'Time', 'Location', 'Operator', 'Flight #', 'Route', 'Type',
#        'Registration', 'cn/In', 'Aboard', 'Fatalities', 'Ground', 'Summary'],
#       dtype='object')

# %%
air.dtypes
# Out:
# Date             object
# Time             object
# Location         object
# Operator         object
# Flight #         object
# Route            object
# Type             object
# Registration     object
# cn/In            object
# Aboard          float64
# Fatalities      float64
# Ground          float64
# Summary          object
# dtype: object

# %%
air.info
# Out:
# <bound method DataFrame.info of             Date   Time                                           Location  \
# 0     09/17/1908  17:18                                Fort Myer, Virginia
# 1     07/12/1912  06:30                            AtlantiCity, New Jersey
# 2     08/06/1913    NaN                 Victoria, British Columbia, Canada
# 3     09/09/1913  18:30                                 Over the North Sea
# 4     10/17/1913  10:30                         Near Johannisthal, Germany
# ...          ...    ...                                                ...
# 5263  05/20/2009  06:30                             Near Madiun, Indonesia
# 5264  05/26/2009    NaN                  Near Isiro, DemocratiRepubliCongo
# 5265  06/01/2009  00:15  AtlantiOcean, 570 miles northeast of Natal, Br...
# 5266  06/07/2009  08:30       Near Port Hope Simpson, Newfoundland, Canada
# 5267  06/08/2009    NaN                  State of Arunachal Pradesh, India
#
# ...

# %%
air.shape
# Out:
# (5268, 13)

# %%
air = air.dropna()

# %%
air.shape
# Out:
# (944, 13)

# %%
print(f"{5268-944} values were removed")
# Out:
# 4324 values were removed

# %%
air_max =air[air['Fatalities'] == air['Fatalities'].max()]

# %%
air_max
# Out:
#             Date   Time                  Location  \
# 2963  03/27/1977  17:07  Tenerife, Canary Islands
#
#                               Operator   Flight #  \
# 2963  Pan American World Airways / KLM  1736/4805
#
#                                               Route  \
# 2963  Tenerife - Las Palmas / Tenerife - Las Palmas
#
#                                       Type   Registration  \
# 2963  Boeing B-747-121 / Boeing B-747-206B  N736PA/PH-BUF
#
#                      cn/In  Aboard  Fatalities  Ground  \
# 2963  19643/11 / 20400/157   644.0       583.0     0.0
#
#                                                 Summary
# 2963  Both aircraft were diverted to Tenerife becaus...

# %%
air_min =air[air['Fatalities'] == air['Fatalities'].min()]

# %%
air_min
# Out:
#             Date   Time                                      Location  \
# 889   10/08/1947  07:55                           Near El Paso, Texas
# 1359  01/19/1955  16:25                              Des Moines, Iowa
# 1443  10/16/1956  06:15                          Over the PacifiOcean
# 1983  07/01/1965  05:29                         Kansas City, Missouri
# 2266  11/22/1968  01:24                     San Francisco, California
# 2486  07/30/1971  14:29                     San Francisco, California
# 2835  08/07/1975  16:11                              Denver, Colorado
# 3341  06/24/1982  20:44                   Mount Galunggung, Indonesia
# 3417  05/05/1983  09:15          En route Miami, FL - Nassau, Bahamas
# 3428  07/23/1983  19:30                       Gimli, Manitoba, Canada
# 3470  02/28/1984  16:16               JFK Airport, New York, New York
# 3541  02/19/1985  10:15        300 nm NW of San Francisco, California
# ...

# %%
air.columns
# Out:
# Index(['Date', 'Time', 'Location', 'Operator', 'Flight #', 'Route', 'Type',
#        'Registration', 'cn/In', 'Aboard', 'Fatalities', 'Ground', 'Summary'],
#       dtype='object')

# %%
air['Year'] = pd.DatetimeIndex(air['Date']).year
# Out:
# C:\Users\abdul\AppData\Local\Temp\ipykernel_3316\3486065852.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   air['Year'] = pd.DatetimeIndex(air['Date']).year

# %%
air.columns
# Out:
# Index(['Date', 'Time', 'Location', 'Operator', 'Flight #', 'Route', 'Type',
#        'Registration', 'cn/In', 'Aboard', 'Fatalities', 'Ground', 'Summary',
#        'Year'],
#       dtype='object')

# %%
plt.bar(air['Year'], air['Fatalities'])
# Out:
# <BarContainer object of 944 artists>

# %%
plt.pie(air)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 plt.pie(location)
#
# NameError: name 'location' is not defined
